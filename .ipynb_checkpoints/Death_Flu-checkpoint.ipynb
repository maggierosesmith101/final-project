# %% [markdown]
# Final Project Biof309: Investigating deaths from Pneumonia and Influenza by state and region.
#
# Author: Margaret Smith
#
# Description: Influenza and Pnemonia are both respiratory infections that can lead to death. Influenza is a highly viral infection that we see spike in the winter time. Although treatable Influenza and Pnemonia are still deadly diseases. This project uses published data provided by the Center for Disease Control on deaths from Pneumonia and Influenza by state and region to exam trends of where in the US majority deaths are occuring.

# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2) Uploading data and getting familiar Your data is required to be free and open to anyone. As such, you should have a URL which anyone can use to download your data:
#
# https://healthdata.gov/dataset/deaths-pneumonia-and-influenza-pi-and-all-deaths-state-and-region-national-center-health

# %%
Death_data = pd.read_csv("https://data.cdc.gov/api/views/rpjd-ejph/rows.csv?accessType=DOWNLOAD")

# %%
Death_data
# Out:
#        Reporting Area  MMWR YEAR  MMWR WEEK  \
# 0      Sacramento, CA       2016          3
# 1       Charlotte, NC       2016          3
# 2     Albuquerque, NM       2016          3
# 3        Columbus, OH       2016          3
# 4          Newark, NJ       2016          3
# ...               ...        ...        ...
# 5143      El Paso, TX       2016         39
# 5144    Charlotte, NC       2016         39
# 5145        Tulsa, OK       2016         39
# 5146      New England       2016         39
# 5147    Cambridge, MA       2016         39
#
#       All causes, by age (years), All Ages**  \
# 0                                      239.0
# 1                                      125.0
# 2                                      165.0
# 3                                      255.0
# 4                                       54.0
# ...                                      ...
# 5143                                    84.0
# 5144                                   132.0
# 5145                                   147.0
# 5146                                   486.0
# 5147                                    13.0
#
#      All causes, by age (years), All Ages**, flag  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 5143                                          NaN
# 5144                                          NaN
# 5145                                          NaN
# 5146                                          NaN
# 5147                                          NaN
#
#       All causes, by age (years), ≥65 All causes, by age (years), ≥65, flag  \
# 0                               180.0                                   NaN
# 1                                88.0                                   NaN
# 2                               114.0                                   NaN
# 3                               163.0                                   NaN
# 4                                30.0                                   NaN
# ...                               ...                                   ...
# 5143                             63.0                                   NaN
# 5144                             92.0                                   NaN
# 5145                            100.0                                   NaN
# 5146                            350.0                                   NaN
# 5147                              8.0                                   NaN
#
#       All causes, by age (years), 45–64  \
# 0                                  48.0
# 1                                  25.0
# 2                                  39.0
# 3                                  67.0
# 4                                  17.0
# ...                                 ...
# 5143                               15.0
# 5144                               25.0
# 5145                               32.0
# 5146                               87.0
# 5147                                2.0
#
#      All causes, by age (years), 45–64, flag  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5143                                     NaN
# 5144                                     NaN
# 5145                                     NaN
# 5146                                     NaN
# 5147                                     NaN
#
#       All causes, by age (years), 25–44  \
# 0                                   9.0
# 1                                  10.0
# 2                                   7.0
# 3                                  15.0
# 4                                   4.0
# ...                                 ...
# 5143                                4.0
# 5144                               10.0
# 5145                                9.0
# 5146                               34.0
# 5147                                3.0
#
#      All causes, by age (years), 25–44, flag  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5143                                     NaN
# 5144                                     NaN
# 5145                                     NaN
# 5146                                     NaN
# 5147                                     NaN
#
#       All causes, by age (years), 1–24 All causes, by age (years), 1–24, flag  \
# 0                                  2.0                                    NaN
# 1                                  NaN                                      -
# 2                                  5.0                                    NaN
# 3                                  6.0                                    NaN
# 4                                  2.0                                    NaN
# ...                                ...                                    ...
# 5143                               1.0                                    NaN
# 5144                               2.0                                    NaN
# 5145                               1.0                                    NaN
# 5146                               7.0                                    NaN
# 5147                               NaN                                      -
#
#       All causes, by age (years), LT 1 All causes, by age (years), LT 1, flag  \
# 0                                  NaN                                      -
# 1                                  2.0                                    NaN
# 2                                  NaN                                      -
# 3                                  4.0                                    NaN
# 4                                  1.0                                    NaN
# ...                                ...                                    ...
# 5143                               1.0                                    NaN
# 5144                               3.0                                    NaN
# 5145                               5.0                                    NaN
# 5146                               8.0                                    NaN
# 5147                               NaN                                      -
#
#       P&I† Total P&I† Total, flag                                 Location 1  \
# 0           15.0              NaN    Sacramento, CA\n(38.582087, -121.50012)
# 1            7.0              NaN     Charlotte, NC\n(35.222936, -80.840161)
# 2           13.0              NaN  Albuquerque, NM\n(35.084248, -106.649241)
# 3           19.0              NaN       Columbus, OH\n(39.920765, -82.80058)
# 4            5.0              NaN        Newark, NJ\n(41.433057, -71.460182)
# ...          ...              ...                                        ...
# 5143         4.0              NaN       El Paso, TX\n(31.76006, -106.492257)
# 5144         6.0              NaN     Charlotte, NC\n(35.222936, -80.840161)
# 5145        18.0              NaN        Tulsa, OK\n(61.096484, -160.967455)
# 5146        33.0              NaN                                        NaN
# 5147         1.0              NaN     Cambridge, MA\n(42.365248, -71.105015)
#
#       Location 2
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 5143         NaN
# 5144         NaN
# 5145         NaN
# 5146         NaN
# 5147         NaN
#
# [5148 rows x 19 columns]

# %%
Death_data.shape
# Out:
# (5148, 19)

# %%
Death_data.isna().sum()
# Out:
# Reporting Area                                     0
# MMWR YEAR                                          0
# MMWR WEEK                                          0
# All causes, by age (years), All Ages**           318
# All causes, by age (years), All Ages**, flag    4830
# All causes, by age (years), ≥65                  324
# All causes, by age (years), ≥65, flag           4824
# All causes, by age (years), 45–64                370
# All causes, by age (years), 45–64, flag         4778
# All causes, by age (years), 25–44                790
# All causes, by age (years), 25–44, flag         4358
# All causes, by age (years), 1–24                1847
# All causes, by age (years), 1–24, flag          3301
# All causes, by age (years), LT 1                2143
# All causes, by age (years), LT 1, flag          3005
# P&I† Total                                       849
# P&I† Total, flag                                4299
# Location 1                                       390
# Location 2                                      5148
# dtype: int64

# %%
# Out:
# Empty DataFrame
# Columns: [geoid, Region, State, age, season, MMWR Year/Week, Deaths from influenza, Deaths from pneumonia, Deaths from pneumonia and influenza, All Deaths, Pecent of deaths due to pneumonia or influenza, pecent complete]
# Index: []
