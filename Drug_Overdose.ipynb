# %% [markdown]
# Trigger Warning
#
# Final Project Biof309: Accidental Drug Related Deaths in Connecticut from 2012-2018
#
# Author: Margaret Smith
#
# Description: For people under the age of 50 in the United States, accidental drug overdose is the leading cause of death. Currently, there is a dramatic increase in overdose deaths in the Northeast and non-Hispanic whites have the highest rates of overdose deaths. Many of these deaths are preventable and a national hotline is set up to help those with substance use disorders 1-800-662-HELP (4357).

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2) Uploading data and getting familiar Your data is required to be free and open to anyone. As such, you should have a URL which anyone can use to download your data:
#
# https://catalog.data.gov/dataset/accidental-drug-related-deaths-january-2012-sept-2015

# %%
DO_data = pd.read_csv("https://data.ct.gov/api/views/rybz-nyjw/rows.csv?accessType=DOWNLOAD")

# %%
DO_data
# Out:
#            ID                    Date      DateType   Age     Sex  \
# 0     14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN
# 1     13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male
# 2     16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female
# 3     16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male
# 4     13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male
# ...       ...                     ...           ...   ...     ...
# 5100  15-0466  09/08/2015 12:00:00 AM  DateReported  43.0    Male
# 5101  17-0618  07/22/2017 12:00:00 AM  DateReported  21.0    Male
# 5102  18-0646  08/14/2018 12:00:00 AM   DateofDeath  30.0    Male
# 5103  14-0124  03/16/2014 12:00:00 AM   DateofDeath  33.0    Male
# 5104  16-0637  09/15/2016 12:00:00 AM   DateofDeath  33.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  DeathCity  \
# 0              NaN            NaN             NaN            NaN        NaN
# ...

# %%
DO_data.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
DO_data.shape
# Out:
# (5105, 41)

# %% [markdown]
# There are 5105 rows and 41 columns in this data.

# %%
DO_data.isna().sum()
# Out:
# ID                        0
# Date                      2
# DateType                  2
# Age                       3
# Sex                       6
# Race                     13
# ResidenceCity           173
# ResidenceCounty         797
# ResidenceState         1549
# DeathCity                 5
# DeathCounty            1100
# Location                 24
# LocationifOther        4515
# DescriptionofInjury     780
# InjuryPlace              66
# InjuryCity             1756
# InjuryCounty           2741
# InjuryState            3681
# COD                       0
# OtherSignifican        4936
# Heroin                 2576
# Cocaine                3584
# Fentanyl               2873
# FentanylAnalogue       4716
# Oxycodone              4498
# Oxymorphone            4997
# Ethanol                3858
# Hydrocodone            4987
# Benzodiazepine         3762
# Methadone              4631
# Amphet                 4946
# Tramad                 4975
# Morphine_NotHeroin     5063
# ...

# %% [markdown]
# 7) Give me a problem statement
#
# Which gender had the highest death rate from accidental drug overdose in CT?

# %%
DO_data["Sex"].value_counts(). plot(kind="bar")
plt.title('Total Drug Overdose Death')
plt.xlabel('Gender')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# Males had the highest death rate from overdose in a 7 year period

# %%
DO_data["Race"].value_counts(). plot(kind="bar")
plt.title('Total Drug Overdose Death')
plt.xlabel('Ethnicity')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# Whites had the highest overdose death rate in CT between 2012-2018
